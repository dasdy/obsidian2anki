# %%
import ankipandas

# %%
# %ls
# Out:
# __init__.py    explore.ipynb

# %%
c = ankipandas.Collection()
# Out:
# INFO: Searching for database. This might take some time. You can speed this up by specifying a search path or directly entering the path to your database.
# WARNING: The search will stop at the first hit, so please verify that the result is correct (for example in case there might be more than one Anki installation)

# %%
c.path
# Out:
# PosixPath('/Users/dasd/Library/Application Support/Anki2/User 1/collection.anki2')

# %%
c.cards
# Out:
#                          nid  cord        cmod  cusn     ctype cqueue  cdue  \
# cid
# 1685801081295  1685801081294     0  1685801131    -1   relearn    due   213
# 1685801081297  1685801081296     0  1685801132    -1   relearn    due   212
# 1685801081299  1685801081298     0  1685801134    -1   relearn    due   212
# 1685801081301  1685801081300     0  1685801135    -1   relearn    due   213
# 1685801081303  1685801081302     0  1685801137    -1   relearn    due   213
# ...                      ...   ...         ...   ...       ...    ...   ...
# 1685801082745  1685801082744     0  1685801116    -1  learning    new     0
# 1685801082747  1685801082746     0  1685801116    -1  learning    new     0
# 1685801082749  1685801082748     0  1685801116    -1  learning    new     0
# 1685801082751  1685801082750     0  1685801116    -1  learning    new     0
# 1685801082753  1685801082752     0  1685801116    -1  learning    new     0
#
# ...

# %%
c.cards.help_cols()
# Out:
#         AnkiColumn  Table                                        Description  \
# Column
# cdeck          NaN  cards                           Name of the current deck
# cdue           due  cards  Due is used differently for different card typ...
# cfactor     factor  cards  The new ease factor of the card in permille (p...
# civl           ivl  cards  The new interval that the card was pushed to a...
# clapses     lapses  cards  The number of times the card went from a "was ...
# cleft         left  cards  Of the form ``a*1000+b``, with: ``b`` the numb...
# cmod           mod  cards                  Modification time [epoch seconds]
# codeck         NaN  cards  Original deck: only used when the card is curr...
# codue         odue  cards  Original due: only used when the card is curre...
# cord           ord  cards  Identifies which of the card templates the car...
# cqueue       queue  cards  Can take the value ‘sched buried’, ‘user burie...
# ...

# %%
c.notes
# Out:
#                     nguid        nmod  nusn ntags  \
# nid
# 1685800080417  LT93/l]VS2  1685800080    -1    []
# 1685801081294  t1.3#N9VAi  1685801081    -1    []
# 1685801081296  r1;>DO?8*i  1685801081    -1    []
# 1685801081298  f}A&ZP&bKF  1685801081    -1    []
# 1685801081300  k2C{JRM|W$  1685801081    -1    []
# ...                   ...         ...   ...   ...
# 1685801082744  D,Yy=Rw]eJ  1685801081    -1    []
# 1685801082746  p-m(CDBG(v  1685801081    -1    []
# 1685801082748  iD!1?xM;!B  1685801081    -1    []
# 1685801082750  F3JHoLv%WU  1685801081    -1    []
# 1685801082752  v8$2MTf)7}  1685801081    -1    []
#
#                                                  nflds             nmodel
# nid
# 1685800080417                                    [,  ]        Words Model
# 1685801081294  [a co třeba,  how about, як на рахунок]  Words Model-733cf
# 1685801081296                         [a proto,  тому]  Words Model-733cf
# ...

# %%
c.notes.help_cols()
# Out:
#        AnkiColumn  Table                                        Description  \
# Column
# nflds        flds  notes  Fields of the card as list. In the raw anki da...
# nguid        guid  notes  Globally Unique Id, almost certainly used for ...
# nmod          mod  notes              Modification timestamp, epoch seconds
# nmodel        NaN  notes                                  Name of the model
# ntags        tags  notes  Tags of the note as list. In the raw anki data...
# nusn          usn  notes  This column (update sequence number) is used t...
#
#         Native  Default
# Column
# nflds     True     True
# nguid     True     True
# nmod      True     True
# nmodel   False     True
# ntags     True     True
# nusn      True     True
